# %%
import numpy as np

size = int(input())
A = np.random.random((size,size))
print(A)
n = int(size/2)
B = np.random.random((n,n))
for i in range(0,n):
  for j in range(0,n):
    B[i,j] = np.max(A[2*i:2*i+2,2*j:2*j+2])
print(B)
