# %%
N = int(input())
str = input()
A = str.split()
L = []
for i in range(N):
  L.append(0)
for i in range(len(A)):
  if(int(A[i])<=N):
    L[int(A[i])-1]+=1
  else:
    for j in range(0,len(L)):
      L[j]=max(L)
for i in range(N):
  print(L[i], end =' ')
